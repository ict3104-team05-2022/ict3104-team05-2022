# %% [markdown]
# # Setup

# %%
# !conda remove -n ICT3104 --all -y

# %%
# !conda env create -n ICT3104 --file environment.yml
# Out:
# Collecting package metadata (repodata.json): ...working... done
# Solving environment: ...working... done
#
# Downloading and Extracting Packages
#
# ipython-8.4.0        | 552 KB    |            |   0%
# ipython-8.4.0        | 552 KB    | 2          |   3%
# ipython-8.4.0        | 552 KB    | ########## | 100%
# ipython-8.4.0        | 552 KB    | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... failed
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/bin/tclsh.exe'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/bin/tclsh86.exe'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/bin/tclsh86t.exe'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/bin/wish.exe'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/bin/wish86.exe'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/bin/wish86t.exe'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/DECkeysym.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/HPkeysym.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/Sunkeysym.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/X.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/XF86keysym.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/Xatom.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/Xfuncproto.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/Xlib.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/Xutil.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/ap_keysym.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/cursorfont.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/keysym.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/X11/keysymdef.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/itcl.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/itclDecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tcl.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tclDecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tclOO.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tclOODecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tclPlatDecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tclTomMath.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tclTomMathDecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tdbc.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tdbcDecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tk.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tkDecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tkIntXlibDecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/include/tkPlatDecls.h'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/dde1.4/pkgIndex.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/itcl4.2.2/itcl.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/itcl4.2.2/itclHullCmds.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/itcl4.2.2/itclWidget.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/itcl4.2.2/pkgIndex.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/itcl4.2.2/test_Itcl_CreateObject.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/nmake/nmakehlp.c'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/nmake/tcl.nmake'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/reg1.3/pkgIndex.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/sqlite3.36.0/pkgIndex.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/auto.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/clock.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/ascii.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/big5.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cns11643.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1250.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1251.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1252.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1253.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1254.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1255.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1256.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1257.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp1258.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp437.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp737.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp775.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp850.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp852.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp855.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp857.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp860.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp861.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp862.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp863.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp864.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp865.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp866.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp869.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp874.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp932.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp936.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp949.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/cp950.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/dingbats.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/ebcdic.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/euc-cn.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/euc-jp.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/euc-kr.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/gb12345.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/gb1988.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/gb2312-raw.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/gb2312.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso2022-jp.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso2022-kr.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso2022.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-1.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-10.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-11.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-13.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-14.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-15.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-16.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-2.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-3.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-4.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-5.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-6.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-7.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-8.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/iso8859-9.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/jis0201.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/jis0208.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/jis0212.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/koi8-r.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/koi8-u.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/ksc5601.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macCentEuro.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macCroatian.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macCyrillic.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macDingbats.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macGreek.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macIceland.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macJapan.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macRoman.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macRomania.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macThai.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macTurkish.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/macUkraine.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/shiftjis.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/symbol.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/encoding/tis-620.enc'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/history.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/http1.0/http.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/http1.0/pkgIndex.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/init.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/opt0.4/optparse.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/opt0.4/pkgIndex.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/package.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/parray.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/safe.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tclIndex'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tm.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Adak'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Anchorage'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Anguilla'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Antigua'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Araguaina'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Aruba'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Asuncion'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Atikokan'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Atka'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Bahia'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Bahia_Banderas'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Barbados'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Belem'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Belize'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Blanc-Sablon'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Boa_Vista'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Bogota'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Boise'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Buenos_Aires'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Cambridge_Bay'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Campo_Grande'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Cancun'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Caracas'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Catamarca'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Cayenne'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Cayman'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Chicago'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Chihuahua'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Coral_Harbour'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Cordoba'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Costa_Rica'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Creston'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Cuiaba'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Curacao'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Danmarkshavn'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Dawson'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Dawson_Creek'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Denver'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Detroit'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Dominica'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Edmonton'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Eirunepe'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/El_Salvador'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Ensenada'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Fort_Nelson'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Fort_Wayne'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Fortaleza'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Glace_Bay'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Godthab'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Goose_Bay'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Grand_Turk'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Grenada'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Guadeloupe'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Guatemala'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Guayaquil'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Guyana'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Halifax'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Havana'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Hermosillo'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indiana/Indianapolis'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indiana/Knox'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indiana/Marengo'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indiana/Petersburg'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indiana/Tell_City'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indiana/Vevay'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indiana/Vincennes'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indiana/Winamac'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Indianapolis'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Inuvik'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Iqaluit'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tcl8.6/tzdata/America/Jamaica'
# ...
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/sayings.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/search.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/spin.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/states.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/style.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/text.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/textpeer.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/toolbar.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/tree.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/ttkbut.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/ttkmenu.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/ttknote.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/ttkpane.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/ttkprogress.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/ttkscale.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/twind.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/unicodeout.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/demos/vscale.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/dialog.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/entry.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/focus.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/fontchooser.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/iconlist.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/icons.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/images/README'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/images/logo.eps'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/images/pwrdLogo.eps'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/listbox.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/megawidget.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/menu.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/mkpsenc.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/msgbox.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/obsolete.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/optMenu.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/palette.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/panedwindow.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/pkgIndex.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/safetk.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/scale.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/scrlbar.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/spinbox.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/tclIndex'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/tearoff.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/text.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/tk.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/tkfbox.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/altTheme.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/aquaTheme.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/button.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/clamTheme.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/classicTheme.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/combobox.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/cursors.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/defaults.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/entry.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/fonts.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/menubutton.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/notebook.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/panedwindow.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/progress.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/scale.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/scrollbar.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/sizegrip.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/spinbox.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/treeview.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/ttk.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/utils.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/vistaTheme.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/winTheme.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/ttk/xpTheme.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/unsupported.tcl'
# specified in the package manifest cannot be found.
#
# CondaVerificationError: The package for tk located at C:\Users\Eddie\.conda\pkgs\tk-8.6.12-h8ffe710_0
# appears to be corrupted. The path 'Library/lib/tk8.6/xmfbox.tcl'
# specified in the package manifest cannot be found.

# %%
# !conda env list

# %%
# !conda activate ICT3104

# %%
# Ensure environment is working
import torch
import timm
import sklearn
import numpy

# %% [markdown]
# # Example Use

# %% [markdown]
# # Apply Module
